# %%
# Perancangan Arsitektur Model

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pyswarms as ps
import joblib

# Mengunci keacakan untuk hasil yang konsisten
np.random.seed(45)
tf.random.set_seed(45)

# Hyperparameter yang akan digunakan
HIDDEN_NODE = 20
N_PARTICLE = 10

# Nama file input (data mentah)
file_input = "Modified_TN_TX_Varied_Gabungan_Semuanya.csv"

try:
    # Memuat dan membersihkan Data Mentah
    df_raw = pd.read_csv(file_input, delimiter=';', na_values=['-', '8888','9999'])
    df_raw.interpolate(method='linear', inplace=True)
    df_cleaned = df_raw.drop('TANGGAL', axis=1)
    print("Berhasil memuat dan membersihkan data mentah.")

    # Mendefinisikan Fitur dan Target
    targets = ['TAVG', 'RH_AVG', 'FF_AVG', 'DDD_X']
    features = ['TN', 'TX', 'RR', 'SS', 'FF_X']
    
    X = df_cleaned[features]
    y = df_cleaned[targets]
    print(f"\nFitur (X) yang digunakan: {features}")
    print(f"Target (y) yang digunakan: {targets}")

    # Normalisasi dan Pembagian Data
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)
    y_scaled = scaler_y.fit_transform(y)

    X_train, X_test, y_train, y_test = train_test_split(
        X_scaled, y_scaled, test_size=0.2, random_state=45
    )
    print("Data berhasil dinormalisasi dan dibagi (80:20).")

    # Pelatihan Model
    # Fungsi untuk membuat model Backpropagation Neural Network (BPNN)
    def create_bpnn_model(n_inputs, n_outputs):
        model = Sequential() # Membuat model sequential dengan Keras untuk struktur jaringan saraf
        model.add(Dense(HIDDEN_NODE, input_dim=n_inputs, activation='relu')) # Menambahkan lapisan tersembunyi dengan jumlah node HIDDEN_NODE dan aktivasi ReLU
        model.add(Dense(n_outputs, activation='linear')) # Menambahkan lapisan output dengan jumlah node sesuai target (n_outputs) dan aktivasi linear
        return model
    
    # Membuat model sementara untuk optimasi PSO
    temp_model = create_bpnn_model(n_inputs=X_train.shape[1], n_outputs=y_train.shape[1]) # n_inputs diambil dari jumlah kolom X_train, n_outputs dari jumlah kolom y_train

    # Fungsi untuk menetapkan bobot model dari partikel PSO
    def set_model_weights_from_particle(particle, model):
        shapes = [w.shape for w in model.get_weights()]
        args, start = [], 0
        for shape in shapes: # Mengubah partikel menjadi bobot model sesuai dengan bentuk aslinya
            end = start + np.prod(shape)
            args.append(particle[start:end].reshape(shape))
            start = end
        model.set_weights(args) # Menetapkan bobot ke model

    # Fungsi fitness untuk PSO: menghitung Mean Squared Error (MSE) untuk setiap partikel
    def fitness_function(particle, model, X, y):
        set_model_weights_from_particle(particle, model) # Menetapkan bobot dari partikel ke model
        y_pred = model.predict(X, verbose=0)
        mse = np.mean((y - y_pred)**2) # Menghitung MSE antara prediksi dan target aktual
        return mse

    # Fungsi objektif untuk PSO: menghitung MSE untuk seluruh partikel dalam swarm
    def f(swarm_particles, model, X, y):
        n_particles = swarm_particles.shape[0]
        y_np = y.to_numpy() if isinstance(y, pd.DataFrame) else y # Mengonversi y ke numpy array jika dalam bentuk DataFrame
        # Menghitung MSE untuk setiap partikel
        dist = [fitness_function(swarm_particles[i], model, X, y_np) for i in range(n_particles)]
        return np.array(dist)
    
    # Memulai optimasi bobot model menggunakan Particle Swarm Optimization (PSO)
    print(f"\n--- Memulai Optimasi PSO (n_particles={N_PARTICLE}) ---")
    n_params = temp_model.count_params() # Menghitung jumlah parameter (bobot dan bias) dalam model
    options = {'c1': 0.5, 'c2': 0.3, 'w': 0.9} # Menentukan parameter PSO: c1 (kognitif), c2 (sosial), w (inertia)
    # Membuat optimizer PSO dengan jumlah partikel dan dimensi sesuai jumlah parameter
    optimizer = ps.single.GlobalBestPSO(n_particles=N_PARTICLE, dimensions=n_params, options=options)
    # Menjalankan PSO untuk mencari bobot terbaik dengan meminimalkan MSE
    best_cost, best_pos = optimizer.optimize(
        lambda p: f(p, model=temp_model, X=X_train, y=y_train),
        iters=100
    )
    # Menampilkan hasil MSE terendah dari PSO
    print(f"--- Optimasi PSO Selesai. MSE terendah: {best_cost} ---")

    # Memulai pelatihan final model BPNN dengan bobot terbaik dari PSO
    print("\n--- Memulai Pelatihan Final Model BPNN ---")
    final_model = create_bpnn_model(n_inputs=X_train.shape[1], n_outputs=y_train.shape[1])
    # Menetapkan bobot terbaik dari PSO ke model final
    set_model_weights_from_particle(best_pos, final_model)
    # Mengompilasi model dengan optimizer Adam dan loss function MSE
    final_model.compile(optimizer='adam', loss='mean_squared_error')
    # Melatih model dengan data latih, menggunakan data uji untuk validasi
    final_model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
          epochs=800, # Melatih selama 800 epoch
        verbose=1
    )
    # Mengevaluasi performa model pada data uji
    final_loss = final_model.evaluate(X_test, y_test, verbose=0)
    # Menampilkan hasil performa model
    print(f"\n--- HASIL EKSPERIMEN ---")
    print(f"Performa Final Model - MSE pada Data Uji: {final_loss}")

    # Menyimpan Aset Model
    # Nama file diubah untuk mencerminkan fitur baru yang digunakan
    #final_model.save('model_predict_weather_h20_n10_.h5')
    #joblib.dump(scaler_X, 'scaler_X_predict_weather_.pkl')
    #joblib.dump(scaler_y, 'scaler_y_predict_weather_.pkl')
    
    #print("\nModel dan scaler dengan fitur baru berhasil disimpan.")

except FileNotFoundError:
    print(f"Error: File '{file_input}' tidak ditemukan.")
except Exception as e:
    print(f"Terjadi error pada proses utama: {e}")
# Out:
# C:\Users\msi\AppData\Local\Temp\ipykernel_12308\223198998.py:27: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_raw.interpolate(method='linear', inplace=True)
# c:\Users\msi\miniforge3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-09-07 21:34:53,989 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# Berhasil memuat dan membersihkan data mentah.
#
# Fitur (X) yang digunakan: ['TN', 'TX', 'RR', 'SS', 'FF_X']
# Target (y) yang digunakan: ['TAVG', 'RH_AVG', 'FF_AVG', 'DDD_X']
# Data berhasil dinormalisasi dan dibagi (80:20).
#
# --- Memulai Optimasi PSO (n_particles=10) ---
# pyswarms.single.global_best: 100%|██████████|100/100, best_cost=0.0692
# 2025-09-07 21:36:23,276 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0
800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0514 - val_loss: 0.0469
# Epoch 9/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0500 - val_loss: 0.0455
# Epoch 10/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0488 - val_loss: 0.0443
# Epoch 11/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0477 - val_loss: 0.0432
# Epoch 12/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0467 - val_loss: 0.0423
# Epoch 13/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0459 - val_loss: 0.0416
# Epoch 14/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0452 - val_loss: 0.0409
# Epoch 15/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0445 - val_loss: 0.0403
# Epoch 16/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0440 - val_loss: 0.0397
# Epoch 17/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0435 - val_loss: 0.0393
# Epoch 18/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0431 - val_loss: 0.0389
# Epoch 19/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0427 - val_loss: 0.0385
# Epoch 20/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0424 - val_loss: 0.0382
# Epoch 21/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0420 - val_loss: 0.0379
# Epoch 22/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0418 - val_loss: 0.0376
# Epoch 23/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0415 - val_loss: 0.0374
# Epoch 24/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0413 - val_loss: 0.0371
# Epoch 25/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0411 - val_loss: 0.0369
# Epoch 26/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0410 - val_loss: 0.0368
# Epoch 27/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0408 - val_loss: 0.0366
# Epoch 28/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0407 - val_loss: 0.0365
# Epoch 29/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0406 - val_loss: 0.0363
# Epoch 30/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0405 - val_loss: 0.0362
# Epoch 31/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0404 - val_loss: 0.0361
# Epoch 32/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0403 - val_loss: 0.0360
# Epoch 33/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0402 - val_loss: 0.0359
# Epoch 34/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0402 - val_loss: 0.0358
# Epoch 35/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0401 - val_loss: 0.0358
# Epoch 36/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0401 - val_loss: 0.0357
# Epoch 37/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0400 - val_loss: 0.0356
# Epoch 38/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0400 - val_loss: 0.0355
# Epoch 39/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0399 - val_loss: 0.0355
# Epoch 40/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0399 - val_loss: 0.0354
# Epoch 41/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0398 - val_loss: 0.0354
# Epoch 42/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0398 - val_loss: 0.0353
# Epoch 43/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0398 - val_loss: 0.0353
# Epoch 44/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0398 - val_loss: 0.0352
# Epoch 45/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0397 - val_loss: 0.0352
# Epoch 46/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0397 - val_loss: 0.0352
# Epoch 47/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0397 - val_loss: 0.0351
# Epoch 48/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0397 - val_loss: 0.0351
# Epoch 49/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0396 - val_loss: 0.0351
# Epoch 50/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0396 - val_loss: 0.0350
# Epoch 51/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0396 - val_loss: 0.0350
# Epoch 52/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0396 - val_loss: 0.0350
# Epoch 53/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0396 - val_loss: 0.0350
# Epoch 54/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0396 - val_loss: 0.0349
# Epoch 55/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - val_loss: 0.0349
# Epoch 56/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - val_loss: 0.0349
# Epoch 57/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - val_loss: 0.0349
# Epoch 58/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - val_loss: 0.0349
# Epoch 59/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - val_loss: 0.0348
# Epoch 60/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0395 - val_loss: 0.0348
# Epoch 61/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - val_loss: 0.0348
# Epoch 62/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - val_loss: 0.0348
# Epoch 63/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - val_loss: 0.0348
# Epoch 64/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - val_loss: 0.0348
# Epoch 65/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0395 - val_loss: 0.0348
# Epoch 66/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0394 - val_loss: 0.0348
# Epoch 67/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0394 - val_loss: 0.0347
# Epoch 68/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0394 - val_loss: 0.0347
# Epoch 69/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0394 - val_loss: 0.0347
# Epoch 70/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0394 - val_loss: 0.0347
# Epoch 71/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0394 - val_loss: 0.0347
# Epoch 72/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0394 - val_loss: 0.0347
# Epoch 73/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0394 - val_loss: 0.0347
# Epoch 74/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0394 - val_loss: 0.0347
# Epoch 75/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0394 - val_loss: 0.0347
# Epoch 76/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0394 - val_loss: 0.0346
# Epoch 77/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0394 - val_loss: 0.0346
# Epoch 78/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0394 - val_loss: 0.0346
# Epoch 79/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0394 - val_loss: 0.0346
# Epoch 80/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0393 - val_loss: 0.0346
# Epoch 81/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - val_loss: 0.0346
# Epoch 82/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - val_loss: 0.0346
# Epoch 83/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0393 - val_loss: 0.0346
# Epoch 84/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - val_loss: 0.0346
# Epoch 85/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - val_loss: 0.0346
# Epoch 86/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393 - val_loss: 0.0346
# Epoch 87/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393 - val_loss: 0.0346
# Epoch 88/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393 - val_loss: 0.0346
# Epoch 89/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 90/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 91/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 92/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 93/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 94/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 95/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 96/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 97/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 98/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 99/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 100/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 101/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 102/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 103/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 104/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 105/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 106/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - val_loss: 0.0345
# Epoch 107/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 108/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 109/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 110/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 111/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 112/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 113/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 114/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 115/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 116/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 117/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 118/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 119/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 120/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 121/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 122/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 123/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 124/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 125/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 126/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 127/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 128/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 129/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 130/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 131/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 132/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 133/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0392 - val_loss: 0.0345
# Epoch 134/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.0345
# Epoch 135/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.0345
# Epoch 136/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.0345
# Epoch 137/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0391 - val_loss: 0.0345
# Epoch 138/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.0345
# Epoch 139/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.0345
# Epoch 140/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.0345
# Epoch 141/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.0345
# Epoch 142/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.0344
# Epoch 143/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.0345
# Epoch 144/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.0345
# Epoch 145/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.0344
# Epoch 146/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.0345
# Epoch 147/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - val_loss: 0.0345
# Epoch 148/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - val_loss: 0.0345
# Epoch 149/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - val_loss: 0.0345
# Epoch 150/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0390 - val_loss: 0.0345
# Epoch 151/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - val_loss: 0.0345
# Epoch 152/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - val_loss: 0.0345
# Epoch 153/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - val_loss: 0.0345
# Epoch 154/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - val_loss: 0.0345
# Epoch 155/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0390 - val_loss: 0.0345
# Epoch 156/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - val_loss: 0.0344
# Epoch 157/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0390 - val_loss: 0.0344
# Epoch 158/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0390 - val_loss: 0.0344
# Epoch 159/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0390 - val_loss: 0.0344
# Epoch 160/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - val_loss: 0.0344
# Epoch 161/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0390 - val_loss: 0.0344
# Epoch 162/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0389 - val_loss: 0.0344
# Epoch 163/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0389 - val_loss: 0.0344
# Epoch 164/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0389 - val_loss: 0.0344
# Epoch 165/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0389 - val_loss: 0.0344
# Epoch 166/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0389 - val_loss: 0.0344
# Epoch 167/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0389 - val_loss: 0.0344
# Epoch 168/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 169/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 170/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 171/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 172/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 173/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 174/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 175/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 176/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 177/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 178/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 179/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 180/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 181/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 182/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 183/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0344
# Epoch 184/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 185/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 186/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 187/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 188/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 189/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 190/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 191/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 192/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 193/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 194/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 195/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 196/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 197/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 198/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 199/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0388 - val_loss: 0.0343
# Epoch 200/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.
800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384 - val_loss: 0.0341
# Epoch 688/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0341
# Epoch 689/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384 - val_loss: 0.0341
# Epoch 690/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 691/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 692/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 693/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 694/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 695/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 696/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 697/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 698/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 699/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 700/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 701/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 702/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 703/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 704/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 705/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 706/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 707/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 708/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 709/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 710/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 711/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 712/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 713/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 714/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 715/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 716/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 717/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 718/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 719/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 720/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 721/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 722/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 723/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 724/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 725/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 726/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 727/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 728/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 729/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 730/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 731/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 732/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 733/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 734/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 735/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 736/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 737/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 738/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 739/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 740/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 741/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 742/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 743/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 744/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 745/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 746/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 747/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 748/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 749/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 750/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 751/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 752/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 753/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 754/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 755/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 756/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 757/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 758/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 759/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 760/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 761/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 762/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 763/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 764/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 765/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 766/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 767/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 768/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 769/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 770/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 771/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 772/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 773/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 774/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 775/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 776/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 777/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 778/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 779/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 780/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 781/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 782/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 783/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 784/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 785/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 786/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 787/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 788/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 789/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 790/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 791/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 792/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 793/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 794/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 795/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 796/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 797/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 798/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 799/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
# Epoch 800/800
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0340
#
# --- HASIL EKSPERIMEN ---
# Performa Final Model - MSE pada Data Uji: 0.0340050645172596

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pyswarms as ps
import joblib
from sklearn.model_selection import ParameterGrid
import uuid

# Mengunci keacakan untuk hasil yang konsisten
np.random.seed(45)
tf.random.set_seed(45)

# Nama file input (data mentah)
file_input = "Modified_TN_TX_Varied_Gabungan_Semuanya.csv"

try:
    # Memuat dan membersihkan Data Mentah
    df_raw = pd.read_csv(file_input, delimiter=';', na_values=['-', '8888','9999'])
    df_raw.interpolate(method='linear', inplace=True)
    df_cleaned = df_raw.drop('TANGGAL', axis=1)
    print("Berhasil memuat dan membersihkan data mentah.")

    # Mendefinisikan Fitur dan Target
    targets = ['TAVG', 'RH_AVG', 'FF_AVG', 'DDD_X']
    features = ['TN', 'TX', 'RR', 'SS', 'FF_X']
    
    X = df_cleaned[features]
    y = df_cleaned[targets]
    print(f"\nFitur (X) yang digunakan: {features}")
    print(f"Target (y) yang digunakan: {targets}")

    # Normalisasi dan Pembagian Data
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)
    y_scaled = scaler_y.fit_transform(y)

    X_train, X_test, y_train, y_test = train_test_split(
        X_scaled, y_scaled, test_size=0.2, random_state=45
    )
    print("Data berhasil dinormalisasi dan dibagi (80:20).")

    # Fungsi untuk membuat model Backpropagation Neural Network (BPNN)
    def create_bpnn_model(n_inputs, n_outputs, hidden_node):
        model = Sequential()
        model.add(Dense(hidden_node, input_dim=n_inputs, activation='relu'))
        model.add(Dense(n_outputs, activation='linear'))
        return model
    
    # Fungsi untuk menetapkan bobot model dari partikel PSO
    def set_model_weights_from_particle(particle, model):
        shapes = [w.shape for w in model.get_weights()]
        args, start = [], 0
        for shape in shapes:
            end = start + np.prod(shape)
            args.append(particle[start:end].reshape(shape))
            start = end
        model.set_weights(args)

    # Fungsi fitness untuk PSO: menghitung Mean Squared Error (MSE)
    def fitness_function(particle, model, X, y):
        set_model_weights_from_particle(particle, model)
        y_pred = model.predict(X, verbose=0)
        mse = np.mean((y - y_pred)**2)
        return mse

    # Fungsi objektif untuk PSO
    def f(swarm_particles, model, X, y):
        n_particles = swarm_particles.shape[0]
        y_np = y.to_numpy() if isinstance(y, pd.DataFrame) else y
        dist = [fitness_function(swarm_particles[i], model, X, y_np) for i in range(n_particles)]
        return np.array(dist)
    
    # Definisikan parameter grid untuk pencarian
    param_grid = {
        'n_particle': [10, 20],
        'hidden_node': [10, 20],
        'iterations': [50, 75],
        'epochs': [200, 400]
    }

    # Inisialisasi variabel untuk menyimpan hasil terbaik
    best_mse = float('inf')
    best_params = None
    best_model = None
    results = []

    # Lakukan grid search
    print("\n--- Memulai Grid Search untuk Hyperparameter ---")
    for params in ParameterGrid(param_grid):
        print(f"\nMencoba kombinasi: {params}")
        
        # Buat model sementara untuk PSO
        temp_model = create_bpnn_model(
            n_inputs=X_train.shape[1],
            n_outputs=y_train.shape[1],
            hidden_node=params['hidden_node']
        )

        # Optimasi PSO
        n_params = temp_model.count_params()
        options = {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
        optimizer = ps.single.GlobalBestPSO(
            n_particles=params['n_particle'],
            dimensions=n_params,
            options=options
        )
        best_cost, best_pos = optimizer.optimize(
            lambda p: f(p, model=temp_model, X=X_train, y=y_train),
            iters=params['iterations']
        )
        print(f"PSO selesai. MSE PSO: {best_cost}")

        # Pelatihan final model
        final_model = create_bpnn_model(
            n_inputs=X_train.shape[1],
            n_outputs=y_train.shape[1],
            hidden_node=params['hidden_node']
        )
        set_model_weights_from_particle(best_pos, final_model)
        final_model.compile(optimizer='adam', loss='mean_squared_error')
        final_model.fit(
            X_train, y_train,
            validation_data=(X_test, y_test),
            epochs=params['epochs'],
            verbose=0
        )

        # Evaluasi model
        final_loss = final_model.evaluate(X_test, y_test, verbose=0)
        print(f"MSE pada data uji: {final_loss}")

        # Simpan hasil
        results.append({
            'params': params,
            'pso_mse': best_cost,
            'test_mse': final_loss
        })

        # Perbarui model terbaik
        if final_loss < best_mse:
            best_mse = final_loss
            best_params = params
            best_model = final_model

    # Tampilkan hasil grid search
    print("\n--- Hasil Grid Search ---")
    print("Kombinasi hyperparameter terbaik:")
    print(f"Parameter: {best_params}")
    print(f"MSE pada data uji: {best_mse}")

    # Simpan model dan scaler terbaik
    # model_filename = f"model_predict_weather_h{best_params['hidden_node']}_n{best_params['n_particle']}.h5"
    # scaler_X_filename = f"scaler_X_predict_weather_h{best_params['hidden_node']}_n{best_params['n_particle']}.pkl"
    # scaler_y_filename = f"scaler_y_predict_weather_h{best_params['hidden_node']}_n{best_params['n_particle']}.pkl"
    
    best_model.save(model_filename)
    joblib.dump(scaler_X, scaler_X_filename)
    joblib.dump(scaler_y, scaler_y_filename)
    
    print(f"\nModel dan scaler terbaik disimpan sebagai:")
    print(f"Model: {model_filename}")
    print(f"Scaler X: {scaler_X_filename}")
    print(f"Scaler y: {scaler_y_filename}")

except FileNotFoundError:
    print(f"Error: File '{file_input}' tidak ditemukan.")
except Exception as e:
    print(f"Terjadi error pada proses utama: {e}")
